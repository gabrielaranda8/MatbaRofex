# %%
import pandas

# %%
#cargamos nuestro archivo csv

planilla = pandas.read_csv('datasetRofex3.csv')
planilla
# Out:
#         Id                     Fecha  Open  High  Low  Last  Cierre  Aj.Dif.  \
# 0        1  05/01/2004 12:00:00 a.m.   0.0   0.0  0.0   0.0   221.0     13.0
# 1        2  06/01/2004 12:00:00 a.m.   0.0   0.0  0.0   0.0   221.0      0.0
# 2        3  07/01/2004 12:00:00 a.m.   0.0   0.0  0.0   0.0   219.0     -2.0
# 3        4  08/01/2004 12:00:00 a.m.   0.0   0.0  0.0   0.0   220.0      1.0
# 4        5  09/01/2004 12:00:00 a.m.   0.0   0.0  0.0   0.0   220.0      0.0
# ...    ...                       ...   ...   ...  ...   ...     ...      ...
# 3849  3850  23/08/2019 12:00:00 a.m.   0.0   0.0  0.0   0.0   245.0     -1.0
# 3850  3851  26/08/2019 12:00:00 a.m.   0.0   0.0  0.0   0.0   245.0      0.0
# 3851  3852  27/08/2019 12:00:00 a.m.   0.0   0.0  0.0   0.0   242.0     -3.0
# 3852  3853  28/08/2019 12:00:00 a.m.   0.0   0.0  0.0   0.0   240.0     -2.0
# 3853  3854  29/08/2019 12:00:00 a.m.   0.0   0.0  0.0   0.0   241.0      1.0
#
# ...

# %%
#Extraemos la primer columna necesaria

datos = planilla.Cierre
datos
# Out:
# 0       221.0
# 1       221.0
# 2       219.0
# 3       220.0
# 4       220.0
#         ...
# 3849    245.0
# 3850    245.0
# 3851    242.0
# 3852    240.0
# 3853    241.0
# Name: Cierre, Length: 3854, dtype: float64

# %%
#Reconvertimos nuestra columna nuevamente en un dataframe

datos = pandas.DataFrame(datos)
datos
# Out:
#       Cierre
# 0      221.0
# 1      221.0
# 2      219.0
# 3      220.0
# 4      220.0
# ...      ...
# 3849   245.0
# 3850   245.0
# 3851   242.0
# 3852   240.0
# 3853   241.0
#
# [3854 rows x 1 columns]

# %%
#Guardamos nuestro nuevo archivo como csv, con nombre a elección

datos.to_csv('DATOSRFXSOY.csv', header=False, index=False)
